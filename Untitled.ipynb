# %%
import pandas as pd
import numpy as np

# %%
chicago = pd.read_csv('chicago.csv')
chicago.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1423854  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4       45207  2017-01-17 14:53:07  2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year
# 0    Male      1992.0
# 1  Female      1992.0
# 2    Male      1981.0
# 3    Male      1986.0
# 4    Male      1975.0

# %%
stations = []
stations.extend(chicago['Start Station'].to_list())
stations.extend(chicago['End Station'].to_list())
print(len(stations))
# Out:
# 600000

# %%
stations_dict = dict(zip(stations, [stations.count(i) for i in stations]))
print(stations_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6af832ccfe81> in <module>
# ----> 1 stations_dict = dict(zip(stations, [stations.count(i) for i in stations]))
#       2 print(stations_dict)
#
# <ipython-input-5-6af832ccfe81> in <listcomp>(.0)
# ----> 1 stations_dict = dict(zip(stations, [stations.count(i) for i in stations]))
#       2 print(stations_dict)
#
# KeyboardInterrupt:

# %%
def common_month():
    m_series = chicago['Start Time'].str[5:7].value_counts()
    return m_series[m_series == max(m)].index[0]

# %%
months = chicago['Start Time'].str[5:7].value_counts()
m = months[months == np.max(months)].index[0]
print(m)

# %%
# %%timeit
months = chicago['Start Time'].str[5:7].value_counts()
months[months == max(months)].index[0]

# %%
new_york = pd.read_csv('new_york_city.csv')
new_york.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     5688089  2017-06-11 14:55:05  2017-06-11 15:08:21            795
# 1     4096714  2017-05-11 15:30:11  2017-05-11 15:41:43            692
# 2     2173887  2017-03-29 13:26:26  2017-03-29 13:48:31           1325
# 3     3945638  2017-05-08 19:47:18  2017-05-08 19:59:01            703
# 4     6208972  2017-06-21 07:49:16  2017-06-21 07:54:46            329
#
#              Start Station             End Station   User Type  Gender  \
# 0  Suffolk St & Stanton St  W Broadway & Spring St  Subscriber    Male
# 1  Lexington Ave & E 63 St         1 Ave & E 78 St  Subscriber    Male
# 2        1 Pl & Clinton St    Henry St & Degraw St  Subscriber    Male
# 3    Barrow St & Hudson St         W 20 St & 8 Ave  Subscriber  Female
# 4          1 Ave & E 44 St         E 53 St & 3 Ave  Subscriber    Male
#
#    Birth Year
# 0      1998.0
# 1      1981.0
# 2      1987.0
# 3      1986.0
# 4      1992.0

# %%
new_york = pd.read_csv('new_york_city.csv')
new_york.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     300000 non-null  int64
#  1   Start Time     300000 non-null  object
#  2   End Time       300000 non-null  object
#  3   Trip Duration  300000 non-null  int64
#  4   Start Station  300000 non-null  object
#  5   End Station    300000 non-null  object
#  6   User Type      299308 non-null  object
#  7   Gender         270791 non-null  object
#  8   Birth Year     271780 non-null  float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 20.6+ MB

# %%
washington = pd.read_csv('washington.csv')
washington.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1621326  2017-06-21 08:36:34  2017-06-21 08:44:43        489.066
# 1      482740  2017-03-11 10:40:00  2017-03-11 10:46:00        402.549
# 2     1330037  2017-05-30 01:02:59  2017-05-30 01:13:37        637.251
# 3      665458  2017-04-02 07:48:35  2017-04-02 08:19:03       1827.341
# 4     1481135  2017-06-10 08:36:28  2017-06-10 09:02:17       1549.427
#
#                                  Start Station                   End Station  \
# 0                         14th & Belmont St NW                15th & K St NW
# 1                   Yuma St & Tenley Circle NW  Connecticut Ave & Yuma St NW
# 2               17th St & Massachusetts Ave NW                 5th & K St NW
# 3             Constitution Ave & 2nd St NW/DOL    M St & Pennsylvania Ave NW
# 4  Henry Bacon Dr & Lincoln Memorial Circle NW         Maine Ave & 7th St SW
#
#     User Type
# 0  Subscriber
# 1  Subscriber
# 2  Subscriber
# 3    Customer
# 4  Subscriber

# %%
washington.loc[washington['Start Time'].str[5:7] == '04']
# Out:
#         Unnamed: 0           Start Time             End Time  Trip Duration  \
# 3           665458  2017-04-02 07:48:35  2017-04-02 08:19:03       1827.341
# 10          854729  2017-04-17 02:50:51  2017-04-17 03:05:17        866.689
# 11          721887  2017-04-08 01:12:48  2017-04-08 01:52:33       2385.411
# 18          679837  2017-04-03 10:22:19  2017-04-03 10:26:11        231.952
# 20          746605  2017-04-09 11:05:42  2017-04-09 11:26:44       1261.363
# ...            ...                  ...                  ...            ...
# 299986      806988  2017-04-13 11:54:34  2017-04-13 12:18:57       1462.967
# 299990      776923  2017-04-11 11:11:57  2017-04-11 11:40:55       1738.345
# 299993      894445  2017-04-20 05:50:30  2017-04-20 06:10:35       1205.379
# 299995      945535  2017-04-26 03:12:14  2017-04-26 03:41:19       1745.528
# 299998      977621  2017-04-28 07:17:47  2017-04-28 07:56:31       2324.170
#
#                                       Start Station  \
# 3                  Constitution Ave & 2nd St NW/DOL
# 10           37th & O St NW / Georgetown University
# 11                                   10th & G St NW
# 18                                20th & Crystal Dr
# 20      Henry Bacon Dr & Lincoln Memorial Circle NW
# ...                                             ...
# 299986            USDA / 12th & Independence Ave SW
# 299990                                1st & O St NW
# 299993                                8th & H St NW
# 299995                             Lincoln Memorial
# 299998                    Jefferson Dr & 14th St SW
#
#                                               End Station   User Type
# 3                              M St & Pennsylvania Ave NW    Customer
# 10                 37th & O St NW / Georgetown University    Customer
# 11                          5th St & Massachusetts Ave NW    Customer
# 18                                        6th & S Ball St  Subscriber
# 20      Smithsonian-National Mall / Jefferson Dr & 12t...    Customer
# ...                                                   ...         ...
# 299986                           4th & East Capitol St NE    Customer
# 299990                                      8th & O St NW  Subscriber
# 299993                                     13th & H St NE    Customer
# 299995                          Jefferson Dr & 14th St SW    Customer
# 299998               Washington & Independence Ave SW/HHS    Customer
#
# [62620 rows x 7 columns]
